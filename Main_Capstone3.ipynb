# %% [markdown]
# # California Housing Prices

# %% [markdown]
# ![suburban-homes-768x512.jpg](attachment:suburban-homes-768x512.jpg)

# %% [markdown]
# # 1. Business Problem Understanding

# %% [markdown]
# ## Latar Belakang

# %% [markdown]
# ## Outline
# 1. Business Problem Understanding <br>
# 2. Data Understanding <br>
# 3. Data Preprocessing <br>
# 4. Modeling <br>
# 5. Conclusion <br>
# 6. Recommendation <br>

# %% [markdown]
# California Realty Group adalah agen real estate yang fokus membantu klien dalam penjualan dan pencarian properti di California. Dengan tim berpengalaman dan pemahaman mendalam tentang pasar perumahan California, California Realty Group berkomitmen memberikan layanan berkualitas dan solusi efektif di industri perumahan. Berdasarkan informasi dari halaman web Ivoox, Kepala ekonom di Departemen Keuangan California. Layanan keuangan dan real estat memimpin paket di $ 26 miliar dalam pertumbuhan,. Keadaan ini memberikan dorongan pada pertumbuhan bisnis properti di California, di mana banyak orang terlibat dalam berbagai kegiatan seperti bisnis, pariwisata, investasi, dan lainnya, memerlukan properti untuk tinggal di California. Namun, model bisnis yang diterapkan oleh California Realty Group memberikan kebebasan kepada pemilik properti untuk menentukan harga properti mereka. Terkadang pelanggan mengalami kesulitan dalam menentukan harga properti mereka dikarenakan jenis properti, lokasi, dan kondisi properti yang berbeda-beda.Dalam bisnis properti, penting bagi pemilik properti untuk memahami dinamika pasar dan nilai properti mereka agar dapat menetapkan harga yang adil dan menarik bagi calon pembeli

# %% [markdown]
# source : https://ivoox.id/california-masuk-5-ekonomi-terbesar-setelah-inggris/

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Salah satu problematika yang dihadapi oleh California Realty Group adalah mencari solusi untuk mengembangkan model bisnis yang menguntungkan secara finansial, baik untuk pemilik properti maupun pembeli. Dalam situasi di mana California Realty Group memberikan keleluasaan kepada pemilik properti untuk menentukan harga properti mereka sendiri, hal ini dapat menimbulkan kesulitan terkait penentuan harga yang optimal. Dengan semakin banyaknya pemilik properti dan pembeli yang menggunakan layanan King Real Estate Group, kebutuhan untuk menetapkan harga properti secara teliti menjadi semakin penting. Maka dari itu, California Realty Group membutuhkan sebuah sistem yang dapat membantu pemilik properti. Untuk <b> membantu</b> untuk menentukan perkiraan harga properti mereka.

# %% [markdown]
# ## Goals

# %% [markdown]
# Berdasarkan problem statement yang telah ditentukan maka tujuan dari project ini adalah untuk membuat sebuah sistem yang dapat membantu pemilik properti untuk menentukan perkiraan harga properti mereka dan membantu pembeli untuk menentukan harga yang adil dan menarik bagi calon pembeli.
# Bagi california realty group sistem ini dapat membantu meningkatkan keuntungan dan memperluas jangkauan bisnisnya

# %% [markdown]
# ## Analytic Approach
#
# Untuk mencapai tujuan tersebut tim data science akan menggunakan model regresi linear untuk memprediksi harga properti berdasarkan fitur-fitur yang ada. Model regresi linear dipilih karena model ini dapat digunakan untuk memprediksi nilai numerik berdasarkan fitur-fitur yang ada. Selain itu, model ini juga mudah untuk diinterpretasikan sehingga dapat membantu pemilik properti untuk menentukan harga properti mereka.
# Data source : Purwadhika

# %% [markdown]
# ## Metric Evaluation
#
# Dalam evaluasi kinerja model, digunakan tiga metrik utama, yaitu:
#
# **1. Root Mean Squared Error (RMSE)**
# - **Fungsi:** Mengukur seberapa besar kesalahan yang dihasilkan oleh model.
# - **Karakteristik:** Memberikan nilai absolut.
# - **Perhitungan:** Merupakan pengembangan dari Mean Squared Error (MSE) dengan mengambil akar kuadrat dari MSE.
#
# **2. Mean Absolute Error (MAE)**
# - **Fungsi:** Mengukur rata-rata kesalahan absolut dari prediksi model.
# - **Karakteristik:** Memberikan nilai absolut.
# - **Perhitungan:** Menghitung rata-rata dari selisih absolut antara prediksi dan nilai sebenarnya.
#
#  **3. Mean Absolute Percentage Error (MAPE)**
# - **Fungsi:** Mengukur persentase kesalahan absolut rata-rata antara prediksi dan nilai sebenarnya.
# - **Karakteristik:** Memberikan nilai relatif.
# - **Perhitungan:** Menghitung persentase kesalahan absolut rata-rata antara prediksi dan nilai sebenarnya.

# %% [markdown]
# # 2. Data Understanding
#
# | Field               | Description                                           |
# |---------------------|-------------------------------------------------------|
# | longitude           | Koordinat geografis bujur rumah.                      |
# | latitude            | Koordinat geografis lintang rumah.                    |
# | housing_median_age  | Umur median rumah di distrik tertentu.                |
# | total_rooms         | Jumlah total kamar di rumah-rumah distrik.            |
# | total_bedrooms      | Jumlah total kamar tidur di rumah-rumah distrik.      |
# | population          | Jumlah populasi di distrik tersebut.                  |
# | households          | Jumlah rumah tangga di distrik tersebut.              |
# | median_income       | Pendapatan median rumah tangga di distrik tersebut.  |
# | ocean_proximity     | Kedekatan rumah dengan lautan (variabel kategorikal).|
# | median_house_value  | Nilai median rumah di distrik tersebut (variabel target).|
#
# **Singkatnya:**
# Data ini berisi informasi geografis dan statistik sensus tahun 1990 untuk rumah-rumah di distrik California. Fitur-fiturnya melibatkan lokasi, umur median rumah, jumlah kamar, populasi, pendapatan median, dan kedekatan dengan lautan, dengan tujuan memprediksi nilai median rumah di distrik tersebut.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('data_california_house.csv')
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -119.79     36.73                52.0        112.0            28.0
# 1    -122.21     37.77                43.0       1017.0           328.0
# 2    -118.04     33.87                17.0       2358.0           396.0
# 3    -118.28     34.06                17.0       2518.0          1196.0
# 4    -119.81     36.73                50.0        772.0           194.0
#
#    population  households  median_income ocean_proximity  median_house_value
# 0       193.0        40.0         1.9750          INLAND             47500.0
# 1       836.0       277.0         2.2604        NEAR BAY            100000.0
# 2      1387.0       364.0         6.2990       <1H OCEAN            285800.0
# 3      3051.0      1000.0         1.7199       <1H OCEAN            175000.0
# 4       606.0       167.0         2.2206          INLAND             59200.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14448 entries, 0 to 14447
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           14448 non-null  float64
#  1   latitude            14448 non-null  float64
#  2   housing_median_age  14448 non-null  float64
#  3   total_rooms         14448 non-null  float64
#  4   total_bedrooms      14311 non-null  float64
#  5   population          14448 non-null  float64
#  6   households          14448 non-null  float64
#  7   median_income       14448 non-null  float64
#  8   ocean_proximity     14448 non-null  object
#  9   median_house_value  14448 non-null  float64
# dtypes: float64(9), object(1)
# memory usage: 1.1+ MB

# %% [markdown]
# Dengan .info() dapat diketahui bahwa data terdiri dari 14448  data dengan 10 kolom. Setiap kolom sudah memiliki tipe data yang sesuai kecuali ocean_proximity.

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  14448.000000  14448.000000        14448.000000  14448.000000
# mean    -119.566647     35.630093           28.618702   2640.132683
# std        2.006587      2.140121           12.596694   2191.612441
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1451.000000
# 50%     -118.490000     34.260000           29.000000   2125.000000
# 75%     -118.000000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  32627.000000
#
#        total_bedrooms    population    households  median_income  \
# count    14311.000000  14448.000000  14448.000000   14448.000000
# mean       538.260709   1425.157323    499.508929       3.866667
# std        423.577544   1149.580157    383.098390       1.891158
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %% [markdown]
# Dengan menggunakan fungsi describe() dapat diketahui statistika deskripsi dari setiap kolom yang bertipe data numeric. Dari hasil diatas dapat dilihat rentang nilai setiap kolom berbeda sehingga nanti nya kita harus menormalisasikannya.

# %% [markdown]
# # 3. Data Preprocessing

# %% [markdown]
# ## Skimming Data

# %%
#skim the data to see if there are any missing values
pd.DataFrame({
    'feature': df.columns.values,
    'data_type': df.dtypes.values,
    'null_value(%)': df.isna().mean().values * 100,
    'neg_value(%)': [len(df[col][df[col] < 0]) / len(df) * 100 if col in df.select_dtypes(include=[np.number]).columns else 0 for col in df.columns],
    '0_value(%)': [len(df[col][df[col] == 0]) / len(df) * 100 if col in df.select_dtypes(include=[np.number]).columns else 0 for col in df.columns],
    'duplicate' : df.duplicated().sum(),
    'n_unique': df.nunique().values,
    '?_value': [len(df[col][df[col] == '?']) for col in df.columns],
    '?_value(%)': [len(df[col][df[col] == '?']) / len(df) * 100 for col in df.columns],
    'sample_unique': [df[col].unique() for col in df.columns]}
).round(3)
# Out:
#               feature data_type  null_value(%)  neg_value(%)  0_value(%)  \
# 0           longitude   float64          0.000         100.0         0.0
# 1            latitude   float64          0.000           0.0         0.0
# 2  housing_median_age   float64          0.000           0.0         0.0
# 3         total_rooms   float64          0.000           0.0         0.0
# 4      total_bedrooms   float64          0.948           0.0         0.0
# 5          population   float64          0.000           0.0         0.0
# 6          households   float64          0.000           0.0         0.0
# 7       median_income   float64          0.000           0.0         0.0
# 8     ocean_proximity    object          0.000           0.0         0.0
# 9  median_house_value   float64          0.000           0.0         0.0
#
#    duplicate  n_unique  ?_value  ?_value(%)  \
# 0          0       806        0         0.0
# 1          0       836        0         0.0
# ...

# %% [markdown]
# Berdasarkan skimming data diatas kita bisa lihat untuk null value hanya ada di kolom total_bedrooms. Untuk mengatasi hal ini kita bisa menggunakan imputasi dengan menggunakan nilai median atau menghapusnya. Selain itu kita juga bisa melihat bahwa kolom ocean_proximity merupakan kolom kategorikal sehingga nanti nya kita akan melakukan encoding.

# %% [markdown]
# ## Duplicate Data Checking

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Setelah dilakukan langkah pengecekan duplikasi pada data, tidak ditemukan adanya data yang terduplikasi. Proses analisis data dapat menghasilkan informasi yang lebih akurat dikarenakan tidak ada data duplikat yang beresiko dapat menimbulkan hasil analisis yang tidak akurat.

# %%
#heatmap missing values
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <AxesSubplot: >

# %%
#drop isna
df.dropna(inplace=True)

# %% [markdown]
# Hanya satu kolom, yaitu 'total_bedrooms', yang memiliki nilai yang hilang dalam data. Sebelum memutuskan untuk menghapus baris dengan nilai yang hilang, perlu diperhatikan seberapa signifikannya jumlah data yang hilang tersebut. Dalam kasus ini, hanya 137 baris data, atau sekitar 0,94% dari total data, yang memiliki nilai yang hilang dalam kolom 'total_bedrooms'. Berdasarkan analisis tersebut, nilai yang hilang pada kolom 'total_bedrooms' dapat dikategorikan sebagai Missing Completely at Random (MCAR).
#
# Untuk menangani nilai yang hilang, akan dilakukan Listwise Deletion atau menghapus baris yang mengandung data yang kosong. Keputusan ini didasarkan pada persentase yang sangat kecil dari nilai yang hilang (0,95%).

# %%
df['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     6300
# INLAND        4544
# NEAR OCEAN    1855
# NEAR BAY      1610
# ISLAND           2
# Name: ocean_proximity, dtype: int64

# %%
#drop ocean_proximity == 'ISLAND'
df = df[df['ocean_proximity'] != 'ISLAND']

# %% [markdown]
# Mengecheck persebaran pada ocean_proximity dan terlihat Ternyata hanya ada 2 data ocean_proximity yang termasuk dalam kategori ISLAND. Kita akan mengabaikan data ini karena hanya 0,008% dari total data. Sehingga kita akan menghapus data ini.

# %% [markdown]
# ### Outlier Handling

# %%
fig, axes = plt.subplots(3, 3, figsize=(20, 17))
fig.suptitle('Distribution of Features', fontsize=20)

columns = ['longitude', 'latitude', 'housing_median_age', 'total_rooms', 'total_bedrooms', 'population', 'households', 'median_income', 'median_house_value']

for i, column in enumerate(columns):
    row = i // 3
    col = i % 3
    sns.boxplot(ax=axes[row, col], data=df, x=column)
    axes[row, col].set_title(column, fontsize=15)
    axes[row, col].set_xlabel('')

plt.tight_layout()
plt.show()

# %% [markdown]
# Dari plot terlihat beberapa fitur yang memiliki, yaitu **total_rooms**, **total_bedrooms**, **population**, **household**, **median_income**, **median_house_value**, **person_in_house**, **bedroom_in_house** dan **room_in_house**. Terdistribusi tidak normal

# %% [markdown]
# Tahapan yang akan dilakukan dimulai dengan mencari nilai-nilai pada batas outliers, selanjutnya akan dilakukan  Pada tahapan berikutnya akan dicek untuk nilai yang berada di luar batas limit, kemudian dengan domain knowledge akan dipertimbangkan untuk mengeliminasi data yang berada di atas limit atas tersebut untuk proses modeling sehingga nantinya hal tersebut akan menjadi limitasi model.

# %%
df_ori = df.copy()

# %% [markdown]
# ### House Median Age and Median House Value handling

# %%
df['housing_median_age'].describe()
# Out:
# count    14309.000000
# mean        28.608009
# std         12.605857
# min          1.000000
# 25%         18.000000
# 50%         29.000000
# 75%         37.000000
# max         52.000000
# Name: housing_median_age, dtype: float64

# %%
sns.distplot(df['housing_median_age'],bins=50)

plt.show()

# %%
df['housing_median_age'].value_counts().head()
# Out:
# 52.0    890
# 36.0    580
# 35.0    568
# 16.0    518
# 17.0    501
# Name: housing_median_age, dtype: int64

# %% [markdown]
# Data yang tidak biasa ditemukan pada nilai usia median hunian sebesar 52 tahun, yang terlihat tidak sesuai dengan tren yang tergambar dalam grafik. Kemungkinan hal ini disebabkan oleh pengelompokan semua data dengan nilai usia median hunian yang lebih besar dari atau sama dengan 52 tahun menjadi satu nilai. Mengingat bahwa di California terdapat banyak rumah yang berusia lebih dari 52 tahun menurut informasi dari zerodown.com, maka kita akan menghapus kolom yang mengandung data ini.

# %%
#make distplot median_house_value
sns.distplot(df['median_house_value'],bins=50)
# Out:
# <AxesSubplot: xlabel='median_house_value', ylabel='Density'>

# %%
df['median_house_value'].value_counts().head(10)
# Out:
# 500001.0    672
# 137500.0     82
# 162500.0     78
# 225000.0     69
# 187500.0     69
# 112500.0     66
# 350000.0     56
# 87500.0      50
# 67500.0      47
# 150000.0     46
# Name: median_house_value, dtype: int64

# %% [markdown]
# Data pada median_house_value memiliki satu nilai yang tidak biasa, yaitu 500001. Hal ini terlihat tidak konsisten mengingat nilai lainnya biasanya memiliki dua angka terakhir 00, sedangkan nilai tidak biasa ini memiliki angka terakhir 01. Kemungkinan hal ini disebabkan oleh pengelompokan semua data dengan nilai median_house_value yang lebih dari 500000 menjadi satu nilai. Oleh karena itu, untuk memperbaiki hal ini, kita akan menghapus kolom yang mengandung data tersebut.

# %%
#delete outlier
df.drop(df[df['housing_median_age']==52].index | df[df['median_house_value']==500001.0].index, inplace=True)

# %%
def find_anomalies(data):
    q1 = data.quantile(0.25)
    q3 = data.quantile(0.75)
    iqr = q3 - q1
    limit = iqr*1.5
    print(f'IQR: {iqr}')

    limit_bawah = q1 - limit
    limit_atas = q3 + limit
    print(f'limit_bawah: {limit_bawah}')
    print(f'limit_atas: {limit_atas}')

# %%
find_anomalies(df['median_house_value'])
# Out:
# IQR: 127400.0
# limit_bawah: -75500.0
# limit_atas: 434100.0

# %%
#percentage of outlier
len(df[df['median_house_value'] > 434100.0]) / len(df) * 100
# Out:
# 2.1286513362336854

# %%
df.drop(df[df['median_house_value']>434100.0].index, inplace=True)

# %%
sns.boxplot(x='median_house_value',data=df)
# Out:
# <AxesSubplot: xlabel='median_house_value'>

# %%
find_anomalies(df['median_house_value'])
# Out:
# IQR: 123250.0
# limit_bawah: -70650.0
# limit_atas: 422350.0

# %%
#show percentage of outlier
len(df[df['median_house_value'] > 422350.0]) / len(df) * 100
# Out:
# 0.4603905381806636

# %% [markdown]
# Setelah penghapusan outlier dengan menggunakan fungsi find_anomalies masih tersisa 0.4%. Berdasarkan cleaning diatas bisa diartikan kita bisa menggunakan `MAE` dan `MAPE` dikarenakan toleran pada outlier

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12598 entries, 1 to 14447
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           12598 non-null  float64
#  1   latitude            12598 non-null  float64
#  2   housing_median_age  12598 non-null  float64
#  3   total_rooms         12598 non-null  float64
#  4   total_bedrooms      12598 non-null  float64
#  5   population          12598 non-null  float64
#  6   households          12598 non-null  float64
#  7   median_income       12598 non-null  float64
#  8   ocean_proximity     12598 non-null  object
#  9   median_house_value  12598 non-null  float64
# dtypes: float64(9), object(1)
# memory usage: 1.1+ MB

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1        -122.21     37.77                43.0       1017.0           328.0
# 2        -118.04     33.87                17.0       2358.0           396.0
# 3        -118.28     34.06                17.0       2518.0          1196.0
# 4        -119.81     36.73                50.0        772.0           194.0
# 5        -117.79     33.80                11.0      10535.0          1620.0
# ...          ...       ...                 ...          ...             ...
# 14441    -117.10     32.73                24.0       2927.0           704.0
# 14442    -120.06     36.94                19.0        901.0           183.0
# 14443    -121.26     38.27                20.0       1314.0           229.0
# 14444    -120.89     37.48                27.0       1118.0           195.0
# 14447    -115.56     32.80                15.0       1171.0           328.0
#
# ...

# %% [markdown]
# ### Feature Engineering

# %%
df['bedrooms_per_room'] = df['total_bedrooms']/df['total_rooms']
df['population_per_household'] = df['population']/df['households']

# %%
df.drop(['total_bedrooms','population'],axis=1,inplace=True)

# %% [markdown]
# Untuk mengurangi dimensi data, akan dilakukan feature engineering dengan membuat fitur baru berdasarkan fitur yang sudah ada. Fitur yang akan dibuat adalah `bedrooms_per_room` yang didapat dari hasil pembagian fitur `total_bedrooms` dengan fitur `total_rooms`. Selain itu, akan dibuat juga fitur `population_per_household` yang didapat dari hasil pembagian fitur `population` dengan fitur `households`. Fitur `bedrooms_per_room` dan `population_per_household` akan digunakan untuk menggantikan fitur `total_bedrooms` dan `population` yang sudah ada.

# %%
def visualize_heatmap(df):
    # Filter numeric columns
    numeric_df = df.select_dtypes(include=[np.number])

    # Calculate correlation matrix
    correlation_matrix = numeric_df.corr()

    # Set figure size
    plt.figure(figsize=(15, 10))

    # Display heatmap
    sns.heatmap(correlation_matrix, cmap='coolwarm', annot=True, fmt='.2f', linewidths=0.5)

    # Adjust layout
    plt.title('Heatmap of Numeric Column Correlations')
    plt.show()

# Call the function to display the heatmap
visualize_heatmap(df)

# %% [markdown]
# Dengan fokus pada kolom `median_house_value`, kita dapat mengamati hasil korelasi antara kolom tersebut dan seluruh kolom lain dalam dataset.
#
# Dari hasil diatas dapat diketahui fitur `median_house_value` berkorelasi positif kuat dengan fitur `median_income` sebesar 0.66. Selain itu akan mengecek VIIF (Variance Inflation Factor) untuk mengetahui apakah ada fitur yang berkorelasi tinggi dengan fitur `median_house_value`. Jika ada maka fitur tersebut akan dihapus.

# %% [markdown]
# ### VIF (Variance Inflation Factor)

# %% [markdown]
# `VIF`, singkatan dari `Variance Inflation Factor`, adalah ukuran statistik yang digunakan untuk menilai multikolinearitas antar variabel prediktor dalam model regresi. Multikolinearitas muncul ketika dua atau lebih variabel prediktor menunjukkan korelasi yang kuat satu sama lain, sehingga menimbulkan tantangan yang signifikan terhadap proses analisis regresi. bersarkan paper [ Coupling fuzzy clustering](https://www.researchgate.net/publication/340104220_Coupling_fuzzy_clustering_and_cellular_automata_based_on_local_maxima_of_development_potential_to_model_urban_emergence_and_expansion_in_economic_development_zones) bahwa jika nilai VIF lebih dari 10 maka akan terjadi multikolinearitas dan harus di drop. Lalu pada artikel [Multicollinearity in Regression Analysis: Problems, Detection, and Solutions](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5710679/) juga menyebutkan bahwa jika nilai VIF lebih dari 10 maka akan terjadi multikolinearitas dan harus di drop. Berdasarkan penjelasan diatas maka akan dilakukan pengecekan VIF untuk mengetahui apakah ada fitur yang berkorelasi tinggi dengan fitur `median_house_value`. Jika ada maka fitur tersebut akan dihapus. Dan yang terakhir pada artikel [Coporatefinance.com](https://corporatefinanceinstitute.com/resources/data-science/variance-inflation-factor-vif/#:~:text=Generally%2C%20a%20VIF%20above%204,that%20needs%20to%20be%20corrected.) menyatakan bahwa Secara umum, VIF di atas 4 atau toleransi di bawah 0,25 menunjukkan kemungkinan adanya multikolinearitas, dan diperlukan penyelidikan lebih lanjut. Jika VIF lebih tinggi dari 10 atau toleransi lebih rendah dari 0,1, terdapat multikolinearitas signifikan yang perlu diperbaiki.

# %%
#def calculate_vif(df) only for numeric
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calculate_vif(df):
    vif_df = pd.DataFrame(columns = ['Feature', 'VIF'])
    x_var = df.select_dtypes(include=[np.number])
    x_var = x_var.drop(['median_house_value'], axis=1)
    x_var = x_var.dropna()
    vif_df['Feature'] = x_var.columns
    vif_df['VIF'] = [variance_inflation_factor(x_var.values, i) for i in range(len(x_var.columns))]
    return vif_df

calculate_vif(df).sort_values(by='VIF', ascending=False)
# Out:
#                     Feature         VIF
# 0                 longitude  845.223512
# 1                  latitude  587.005339
# 6         bedrooms_per_room   36.792311
# 4                households   28.058166
# 3               total_rooms   26.932518
# 5             median_income   13.244858
# 2        housing_median_age    8.064358
# 7  population_per_household    1.192040

# %%
#drop langitude and latitude
df.drop(['longitude', 'latitude'], axis=1, inplace=True)
calculate_vif(df).sort_values(by='VIF', ascending=False)
# Out:
#                     Feature        VIF
# 2                households  26.313886
# 1               total_rooms  24.273835
# 4         bedrooms_per_room   9.944671
# 0        housing_median_age   6.533288
# 3             median_income   5.517124
# 5  population_per_household   1.189003

# %%
#drop total_bedrooms
df.drop('households', axis=1, inplace=True)
calculate_vif(df).sort_values(by='VIF', ascending=False)
# Out:
#                     Feature       VIF
# 3         bedrooms_per_room  7.454679
# 0        housing_median_age  6.504810
# 2             median_income  4.706086
# 1               total_rooms  2.727251
# 4  population_per_household  1.188418

# %%
calculate_vif(df).sort_values(by='VIF', ascending=False)
# Out:
#                     Feature       VIF
# 3         bedrooms_per_room  7.454679
# 0        housing_median_age  6.504810
# 2             median_income  4.706086
# 1               total_rooms  2.727251
# 4  population_per_household  1.188418

# %% [markdown]
# Berdasarkan perhitungan `VIF` diatas dapat diketahui bahwa fitur longitude, latitude dan household memiliki nilai VIF diatas 10. Maka dari itu fitur-fitur tersebut akan dihapus. lalu tersisa fitur bedrooms_per_room, housing_median_age, median_income, ocean_proximity, population_per_household dan total bedrooms_per_room. Alasan tidak menghapus fitur `bedrooms_per_room' dan `population_per_household  **karena fitur tersebut merupakan hasil feature engineering dari fitur yang sudah ada**. Selain itu, fitur `ocean_proximity` merupakan fitur kategorikal yang akan diubah menjadi numerikal dengan menggunakan metode one hot encoding. dan jika menghapus fitur tersebut(VIF diatas 4) akan mengurangi informasi yang ada.

# %%
df_copy = df.copy()

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import RobustScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer, TransformedTargetRegressor
#import standard scaler
#import categorical encoder ce for ordinal
from sklearn.preprocessing import OrdinalEncoder

# %%
pipeline_robust_scale = Pipeline([
    ('scaler', RobustScaler(with_centering=False))
])

pipe_ordinal_scale = Pipeline([
    #one hot encoder
    # ('onehot', OneHotEncoder(drop='first')),
    ('Onehot', OneHotEncoder()),
    ('scaler', RobustScaler(with_centering=False))
])

transformer = ColumnTransformer([
    ('pipe_robust_scale', pipeline_robust_scale, ['median_income', 'housing_median_age','bedrooms_per_room','population_per_household','total_rooms']),
    ('pipe_ordinal_scale', pipe_ordinal_scale, ['ocean_proximity'])
], remainder='passthrough')
transformer
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('pipe_robust_scale',
#                                  Pipeline(steps=[('scaler',
#                                                   RobustScaler(with_centering=False))]),
#                                  ['median_income', 'housing_median_age',
#                                   'bedrooms_per_room',
#                                   'population_per_household', 'total_rooms']),
#                                 ('pipe_ordinal_scale',
#                                  Pipeline(steps=[('Onehot', OneHotEncoder()),
#                                                  ('scaler',
#                                                   RobustScaler(with_centering=False))]),
#                                  ['ocean_proximity'])])

# %% [markdown]
# Pada tahap ini dilakukan transformasi data menggunakan pipeline dengan menggunakan `RobustScaler` untuk mengurangi efek dari outlier dan `OneHotEncoder` untuk mengubah fitur kategorikal menjadi numerikal. Alasan untuk menggunakan `RobustScaler` adalah karena scaler ini lebih tahan terhadap outlier dibandingkan dengan `StandardScaler` dan `MinMaxScaler`. Selain itu, `OneHotEncoder` digunakan untuk mengubah fitur kategorikal menjadi numerikal karena fitur `ocean_proximity` merupakan fitur kategorikal yang mempunyai unique value dibawah 5.

# %% [markdown]
# # 4 Modeling

# %% [markdown]
# Pada modeling dilakukan cross validation dengan menggunakan 5 fold. Dengan menggunakan 5 fold maka akan didapatkan 5 nilai RMSE, MAE dan MAPE. Dari 5 nilai tersebut akan diambil nilai rata-rata untuk menentukan nilai RMSE, MAE dan MAPE yang terbaik. Model yang akan diuji yaitu `Linear Regression`, `KNN`, `Decision Tree`, `Random Forest`, `XGBoost` dan `LGBM`. Untuk menentukan model terbaik akan digunakan nilai RMSE, MAE dan MAPE terkecil.

# %% [markdown]
# ## Cross Validation

# %%
#make cross validation
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, mean_absolute_percentage_error
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
#lightgbm
from lightgbm import LGBMRegressor
#xgboost
from xgboost import XGBRegressor
#catboost
from catboost import CatBoostRegressor
#import kfold
from sklearn.model_selection import KFold
#gbr
from sklearn.ensemble import GradientBoostingRegressor

#split data
X = df.drop(['median_house_value'], axis=1)
y = df['median_house_value']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=41)

lr = LinearRegression()
knn = KNeighborsRegressor()
dt = DecisionTreeRegressor(random_state=2024)
rf = RandomForestRegressor(random_state=2024)
xgb = XGBRegressor(random_state=2024)
lgbm = LGBMRegressor(random_state=2024, verbose=-1)
gbr = GradientBoostingRegressor(random_state=2024)

# Pemodelan dalam skala logaritmik, kemudian diinversikan kembali untuk proses interpretasi
log_lr = TransformedTargetRegressor(lr, func=np.log, inverse_func=np.exp)
log_knn = TransformedTargetRegressor(knn, func=np.log, inverse_func=np.exp)
log_dt = TransformedTargetRegressor(dt, func=np.log, inverse_func=np.exp)
log_rf = TransformedTargetRegressor(rf, func=np.log, inverse_func=np.exp)
log_xgb = TransformedTargetRegressor(xgb, func=np.log, inverse_func=np.exp)
log_lgbm = TransformedTargetRegressor(lgbm, func=np.log, inverse_func=np.exp)
log_gbr = TransformedTargetRegressor(gbr, func=np.log, inverse_func=np.exp)

# List of all models
model = [
    log_lr,
    log_knn,
    log_dt,
    log_rf,
    log_xgb,
    log_lgbm,
    log_gbr
    

]

scaler = RobustScaler(with_centering=False)

score_mae = []
nilai_mean_mae = []
nilai_std_mae = []

score_rmse = []
nilai_mean_rmse = []
nilai_std_rmse = []

score_mape = []
nilai_mean_mape = []
nilai_std_mape = []


for i in model:
    
    crossval = KFold(n_splits=5, shuffle=True, random_state=2024)

    estimator = Pipeline([
        ('preprocessing', transformer),
        ('scaler', scaler),
        ('model', i)
    ])

    # MAE
    model_cv_mae = cross_val_score(
        estimator, 
        X_train, 
        y_train, 
        cv=crossval, 
        scoring='neg_mean_absolute_error', 
        error_score='raise'
        )

    print(model_cv_mae, i)

    score_mae.append(model_cv_mae)
    nilai_mean_mae.append(model_cv_mae.mean())
    nilai_std_mae.append(model_cv_mae.std())

    # RMSE
    model_cv_rmse = cross_val_score(
        estimator, 
        X_train, 
        y_train, 
        cv=crossval, 
        scoring='neg_root_mean_squared_error', 
        error_score='raise'
        )

    print(model_cv_rmse, i)

    score_rmse.append(model_cv_rmse)
    nilai_mean_rmse.append(model_cv_rmse.mean())
    nilai_std_rmse.append(model_cv_rmse.std())

    # MAPE
    model_cv_mape = cross_val_score(
        estimator, 
        X_train, 
        y_train, 
        cv=crossval, 
        scoring='neg_mean_absolute_percentage_error', 
        error_score='raise'
        )

    print(model_cv_mape, i)

    score_mape.append(model_cv_mape)
    nilai_mean_mape.append(model_cv_mape.mean())
    nilai_std_mape.append(model_cv_mape.std())
# Out:
# [-42045.68461136 -42678.08962405 -42059.70019049 -41468.59243293
#  -43902.73054089] TransformedTargetRegressor(func=<ufunc 'log'>, inverse_func=<ufunc 'exp'>,
#                            regressor=LinearRegression())
# [-58274.01985002 -67716.26445101 -61237.09060164 -58060.20585006
#  -69306.54685935] TransformedTargetRegressor(func=<ufunc 'log'>, inverse_func=<ufunc 'exp'>,
#                            regressor=LinearRegression())
# [-0.24120196 -0.25860654 -0.23829315 -0.24689929 -0.24975762] TransformedTargetRegressor(func=<ufunc 'log'>, inverse_func=<ufunc 'exp'>,
#                            regressor=LinearRegression())
# [-37212.65488386 -37554.6715595  -37946.58889472 -36908.64616919
#  -37573.09648644] TransformedTargetRegressor(func=<ufunc 'log'>, inverse_func=<ufunc 'exp'>,
#                            regressor=KNeighborsRegressor())
# [-52818.86847291 -53047.73988573 -53712.36787627 -50669.38096114
# ...

# %%
pd.DataFrame({
    'model': ['log_lr', 'log_knn', 'log_dt', 'log_rf', 'log_xgb','log_lgbm', 'log_gbr'],
    'mae': nilai_mean_mae,
    'std_mae': nilai_std_mae,
    'rmse': nilai_mean_rmse,
    'std_rmse': nilai_std_rmse,
    'mean_mape': nilai_mean_mape,
    'score_mape': score_mape,
    'std_mape': nilai_std_mape
}).sort_values(by='mean_mape', ascending=False)
# Out:
#       model           mae     std_mae          rmse     std_rmse  mean_mape  \
# 5  log_lgbm -34917.030951  519.823301 -48939.804761   912.531760  -0.207973
# 3    log_rf -35261.226781  535.070473 -49451.470949  1163.078064  -0.210243
# 6   log_gbr -35896.960785  541.713890 -49989.404818  1117.920125  -0.214139
# 4   log_xgb -36660.648260  464.225508 -51142.414775   692.386588  -0.219139
# 1   log_knn -37439.131599  352.566440 -52569.205317  1020.616524  -0.224127
# 0    log_lr -42430.959480  829.409896 -62918.825522  4729.207996  -0.246952
# 2    log_dt -49458.895191  433.110191 -68908.722339  1047.239919  -0.302142
#
#                                           score_mape  std_mape
# 5  [-0.203829965458865, -0.2157892624000977, -0.2...  0.005217
# 3  [-0.2052754363563591, -0.2182165450637571, -0....  0.005020
# 6  [-0.20994185193022527, -0.2236479868453787, -0...  0.005647
# 4  [-0.2170780556767613, -0.22593766554852168, -0...  0.004687
# ...

# %% [markdown]
# Berdasarkan`MAPE` dan `MAE` algoritma lgbm dan rf merupakan top 2 algoritma yang memiliki nilai error terkecil. Selanjutnya akan dilakukan modeling ke data test dengan menggunakan kedua algoritma tersebut. Setelah dilakukan modeling,

# %% [markdown]
# ## Modeling 2 Best Model

# %%
#model terbaik adalah log_gbm
pipe = Pipeline([
    ('preprocessing', transformer),
    # ('scaler', scaler),
    ('model', log_lgbm)
])

pipe.fit(X_train, y_train)

y_pred = pipe.predict(X_test)

print('MAE:', mean_absolute_error(y_test, y_pred))

print('RMSE:', mean_squared_error(y_test, y_pred, squared=False))

print('MAPE:', mean_absolute_percentage_error(y_test, y_pred))

LGBMbeforetuning = pd.DataFrame({
    'Model': ['LGBMRegressor, before tuning'],
    'RMSE': [mean_squared_error(y_test, y_pred, squared=False)],
    'MAE': [mean_absolute_error(y_test, y_pred)],
    'MAPE': [mean_absolute_percentage_error(y_test, y_pred)]
    })
# Out:
# MAE: 35484.591976760275
# RMSE: 49676.569807885884
# MAPE: 0.2122674954967752

# %%
LGBMbeforetuning
# Out:
#                           Model          RMSE           MAE      MAPE
# 0  LGBMRegressor, before tuning  49676.569808  35484.591977  0.212267

# %%
pipe = Pipeline([
    ('preprocessing', transformer),
    # ('scaler', scaler),
    ('model', log_rf)
])

pipe.fit(X_train, y_train)

y_pred = pipe.predict(X_test)

RFbeforetuning = pd.DataFrame({
    'Model': 'Random Forest; Before Tuning',
    'RMSE': [mean_squared_error(y_test, y_pred, squared=False)],
    'MAE': [mean_absolute_error(y_test, y_pred)],
    'MAPE': [mean_absolute_percentage_error(y_test, y_pred)]
    })

RFbeforetuning
# Out:
#                           Model          RMSE           MAE      MAPE
# 0  Random Forest; Before Tuning  49802.315076  35905.445973  0.216882

# %% [markdown]
#     'num_leaves': [ 50, 75, 100],
#     'max_depth': [-1, 10, 20],
#     'min_child_samples': [10, 20, 30],
#     'subsample': [0.7, 0.8, 0.9, 1.0],
#     'colsample_bytree': [0.6, 0.7, 0.8, 0.9, 1.0],
#     'learning_rate': [0.01, 0.05, 0.1,],
#     'n_estimators': [50, 100, 200,],
#     'reg_alpha': [0, 0.1, 0.5, 1],
#     'reg_lambda': [0, 0.1, 0.5, 1],
#     'max_bin': [255, 355, 455],
#     'boosting_type': ['gbdt', 'dart']

# %% [markdown]
# ### Hyper Parameter Tuning LightGBM

# %% [markdown]
# LightGBM menurut [documentation Library LightGBM](https://lightgbm.readthedocs.io/en/stable/) adalah kerangka kerja penguatan gradien yang menggunakan algoritma pembelajaran Decision Tree. Decision Tree yang ditingkatkan oleh gradien merupakan jenis algoritma mesin pembelajaran yang menggunakan pohon keputusan sebagai estimator dari suatu ensemble. Sebuah ensemble terdiri dari banyak model/estimator lemah (pohon keputusan) yang prediksinya digabungkan untuk membuat prediksi akhir.
# Ini dirancang untuk didistribusikan dan efisien dengan keunggulan berikut:
#
# - Kecepatan pelatihan yang lebih cepat dan efisiensi yang lebih tinggi.
#
# - Penggunaan memori yang lebih rendah.
#
# - Akurasi yang lebih baik.
#
# - Dukungan untuk pembelajaran paralel, terdistribusi, dan GPU.
#
# - Mampu menangani data dalam skala besar.

# %% [markdown]
# Setelah memilih model terbaik dari Modeling, langkah berikutnya adalah mengoptimasi model melalui proses tuning hyperparameter.
#
# Penyetelan hyperparameter, yang juga dikenal sebagai optimisasi model, melibatkan pencarian kombinasi hyperparameter yang paling optimal untuk meningkatkan performa model pembelajaran mesin Anda. Hyperparameter ini adalah parameter yang tidak dapat dipelajari secara langsung oleh model selama proses pelatihan dan harus disesuaikan sebelum pelatihan dimulai. Sebaliknya, parameter-model seperti bobot dalam jaringan saraf atau pembagi dalam pohon keputusan-diatur selama proses pelatihan.

# %% [markdown]
# - **Model:** LigthGBM
# - **Search Space:** `num_leaves`, `max_depth`, `min_child_samples`, `subsample`, `colsample_bytree`, `learning_rate`, `n_estimators`, `reg_alpha`, `reg_lambda`, `max_bin`, `boosting_type
# - **Optimation Criteria:** `MAPE`
# - **Search Method:** `RandomizedSearchCV`

# %% [markdown]
# #### LightGBM Parameters
#
# | **Parameter**         | **Description**                          | **Default**   |
# |-----------------------|------------------------------------------|---------------|
# | **boosting_type**     | Variant of boosting                      | gbdt          |
# | **learning_rate**     | Speed of model learning                  | 0.1           |
# | **max_depth**         | No limit on tree depth                   | -1 (tidak ada batasan) |
# | **min_child_samples** | Minimum samples to form a node           | 20            |
# | **n_estimators**      | Number of trees                          | 100           |
# | **num_leaves**        | Maximum leaves per tree                  | 31            |
# | **reg_alpha**         | L1 regularization                        | 0.0           |

# %%
#hyper parametertuning log_lgbm
from sklearn.model_selection import RandomizedSearchCV
#import lightgbm
lightgbm = LGBMRegressor(random_state=2024, verbose=-1)
pipe_hyper = Pipeline([
    ('preprocessing', transformer),
    # ('scaler', scaler),
    ('model', lightgbm)
])

param_grid = {
    'model__num_leaves': [50, 75, 100],
    'model__max_depth': [10, 20, 30],
    'model__learning_rate': [0.01, 0.05, 0.1],
    'model__n_estimators': [50, 100, 200],
    'model__min_child_samples': [10, 20, 30],
    'model__reg_alpha': [0.1, 0.5, 1],
    'model__boosting_type': ['gbdt', 'dart', 'goss'],
}

model_cv = RandomizedSearchCV(
    estimator=pipe_hyper,
    param_distributions=param_grid,
    cv=crossval,
    scoring= 'neg_mean_absolute_percentage_error',
    n_iter=20,
    n_jobs=-1,
    random_state=2024,
)

model_cv.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=KFold(n_splits=5, random_state=2024, shuffle=True),
#                    estimator=Pipeline(steps=[('preprocessing',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('pipe_robust_scale',
#                                                                                Pipeline(steps=[('scaler',
#                                                                                                 RobustScaler(with_centering=False))]),
#                                                                                ['median_income',
#                                                                                 'housing_median_age',
#                                                                                 'bedrooms_per_room',
#                                                                                 'population_per_household',
# ...

# %%
#print best parameter
print(model_cv.best_params_)
print(model_cv.best_score_)
# Out:
# {'model__reg_alpha': 0.5, 'model__num_leaves': 100, 'model__n_estimators': 200, 'model__min_child_samples': 10, 'model__max_depth': 20, 'model__learning_rate': 0.05, 'model__boosting_type': 'dart'}
# -0.20735487502420158

# %%
#delete model__ from best parameter
best_param = model_cv.best_params_
best_param = {k.replace('model__', ''): v for k, v in best_param.items()}
#delete boosting
best_param
# Out:
# {'reg_alpha': 0.5,
#  'num_leaves': 100,
#  'n_estimators': 200,
#  'min_child_samples': 10,
#  'max_depth': 20,
#  'learning_rate': 0.05,
#  'boosting_type': 'dart'}

# %%
#comvert to dataframe
pd.DataFrame(model_cv.cv_results_).sort_values(by='rank_test_score').head(3)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 15      14.115319      0.475606         0.025153        0.007653
# 17       7.583909      0.196316         0.015712        0.005047
# 2        5.652337      0.541502         0.055936        0.042121
#
#    param_model__reg_alpha param_model__num_leaves param_model__n_estimators  \
# 15                    0.5                     100                       200
# 17                    0.5                      50                       200
# 2                     0.5                      50                       200
#
#    param_model__min_child_samples param_model__max_depth  \
# 15                             10                     20
# 17                             30                     30
# 2                              30                     10
#
#    param_model__learning_rate param_model__boosting_type  \
# 15                       0.05                       dart
# ...

# %%
#modeling with best parameter
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
lightgbm = LGBMRegressor(random_state=2024, **best_param)

pipe_tuning = Pipeline([
    ('preprocessing', transformer),
    # ('scaler', scaler),
    ('model', lightgbm)
])

pipe_tuning.fit(X_train, y_train)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000442 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1079
# [LightGBM] [Info] Number of data points in the train set: 8818, number of used features: 9
# [LightGBM] [Info] Start training from score 182889.895441
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('pipe_robust_scale',
#                                                   Pipeline(steps=[('scaler',
#                                                                    RobustScaler(with_centering=False))]),
#                                                   ['median_income',
#                                                    'housing_median_age',
#                                                    'bedrooms_per_room',
# ...

# %%
#predict
y_pred_tuning = pipe_tuning.predict(X_test)

aftertuningLGBM = pd.DataFrame({
    'Model': 'LGBMRegressor, after tuning',
    'RMSE': [mean_squared_error(y_test, y_pred_tuning, squared=False)],
    'MAE': [mean_absolute_error(y_test, y_pred_tuning)],
    'MAPE': [mean_absolute_percentage_error(y_test, y_pred_tuning)]
    })

aftertuningLGBM
# Out:
#                          Model          RMSE           MAE      MAPE
# 0  LGBMRegressor, after tuning  53175.026846  37760.007574  0.211635

# %%
#compare before and after tuning
display(LGBMbeforetuning, aftertuningLGBM)
# Out:
#                           Model          RMSE           MAE      MAPE
# 0  LGBMRegressor, before tuning  49676.569808  35484.591977  0.212267
#                          Model          RMSE           MAE      MAPE
# 0  LGBMRegressor, after tuning  53175.026846  37760.007574  0.211635

# %% [markdown]
# Berdasarkan hasil hyperparameter tuning menggunakan random search dan n iter = 15 didapatkan parameter terbaik berikut :

# %% [markdown]
# # LightGBM Parameters
#
# | **Parameter**         | **Description**                          | **Default**   | **Value**   |
# |-----------------------|------------------------------------------|---------------|-------------|
# | **boosting_type**     | Variant of boosting                      | gbdt          | dart        |
# | **learning_rate**     | Speed of model learning                  | 0.1           | 0.05        |
# | **max_depth**         | No limit on tree depth                   | -1 (tidak ada batasan) | 20          |
# | **min_child_samples** | Minimum samples to form a node           | 20            | 10          |
# | **n_estimators**      | Number of trees                          | 100           | 200         |
# | **num_leaves**        | Maximum leaves per tree                  | 31            | 100         |
# | **reg_alpha**         | L1 regularization                        | 0.0           | 0.5         |

# %% [markdown]
# Dan menghsilkan `RMSE : 49676.569808`	, `MAE : 35484.591977`, `MAPE : 0.212267`. Dan setelah dibandingkan dengan base model tanpa hyper parameter tuning terjadi penurunan perfoma disemua metrik evaluasi. Sehingga digunakan base model tanpa hyper parameter tuning untuk melakukan prediksi pada data test. Dikarenakan  performa pada perangkat yang digunakan tidak mampu untuk melakukan hyper parameter tuning yang lebih banyak. MAPE : 0.212267 berdasarkan paper dari Lewis 1982 termasuk dalam kategori `Reasonable Forecast`

# %% [markdown]
# ![Interpretation-of-MAPE-Results-for-Forecasting-Accuracy.png](attachment:Interpretation-of-MAPE-Results-for-Forecasting-Accuracy.png)

# %% [markdown]
# ## Actual vs Prediction

# %%
#actual vs prediction
plt.figure(figsize=(10, 8))
sns.scatterplot(x=y_test, y=y_pred)
plt.xlabel('Actual')
plt.ylabel('Prediction')
plt.title('Actual vs Prediction')
plt.show()

# %% [markdown]
# Dari plot yang disajikan, terlihat bahwa terdapat perbedaan yang signifikan antara harga aktual dan prediksi. masih terlihat bahwa mayoritas titik data berada di atas garis diagonal. Seiring dengan meningkatnya nilai `median_house_value`, perbedaan antara prediksi dan nilai aktual cenderung semakin besar, seperti yang tercermin dalam visualisasi tersebut. Hal ini menunjukkan kecenderungan model untuk melakukan underestimasi terhadap properti dengan nilai `median_house_value` yang tinggi, terlihat dari jarak antara titik-titik tersebut dengan garis diagonal.

# %% [markdown]
# ### Residual plot

# %% [markdown]
# Residual plot dalam konteks regresi adalah grafik yang menunjukkan selisih antara nilai aktual dari variabel respons (y) dan nilai yang diprediksi oleh model regresi. Ini adalah grafik dari residu, yaitu selisih antara nilai aktual dan nilai yang diprediksi oleh model regresi.
#
# Secara teknis, residual adalah selisih antara nilai aktual (y) dan nilai prediksi (ŷ) dari model regresi, yaitu:
#
# `residual = y_test - y_pred` <br>
#
# Residual plot memungkinkan untuk mengevaluasi apakah terdapat pola atau struktur tertentu dalam residu yang tersisa setelah model regresi diterapkan. Ini adalah alat penting dalam menganalisis kualitas model regresi. Dengan menganalisis pola-pola dalam residual plot, kita dapat mengidentifikasi apakah ada asumsi-asumsi yang dilanggar oleh model regresi, seperti heteroskedastisitas (variasi yang tidak konstan dalam residual), atau non-linearitas.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# create residual plot
plt.figure(figsize=(15, 8))
residual = y_test - y_pred
sns.scatterplot(x=y_pred,y=residual)
plt.axhline(y=0, color='r', ls='--')
plt.xlabel('y_pred')
plt.ylabel('residual')
plt.title('Residual Plot  LGBM Before Tuning')
plt.show()

# %%
#residual plot
import statsmodels.api as sm
import plotly.express as px
import plotly.graph_objects as go


residual = y_test - y_pred

#use plotly
fig = px.scatter(x=y_pred, y=residual, labels={'x':'y_pred', 'y':'residual'})
fig.add_trace(go.Scatter(x=y_pred, y=[0 for i in range(len(y_pred))], mode='lines', name='mean'))
fig.show()

# %% [markdown]
# Beberapa data memiliki kesalahan yang signifikan, meskipun jumlahnya terbatas. Dalam visualisasi di atas, beberapa contoh menunjukkan prediksi yang lebih tinggi dari harga aktual (overestimation), sementara yang lain menunjukkan sebaliknya (underestimation). Meskipun perbedaan ini tidak terlalu besar, sebagian besar prediksi hampir mencapai harga aktual. Dengan MAPE sekitar 21%, Bisa dilihat bahwa banyak residu yang ada diatas 200k dan dibawah 140k ini cenderung anomalinya lebih besar dibandingkan dengan residu yang lain.

# %% [markdown]
# #### Residual Analysis: Normality Assumption

# %%
df_residual = pd.DataFrame(X_test)
df_residual['actual'] = y_test
df_residual['prediction'] = y_pred
df_residual['residual'] = residual
df_residual['percentage_residual'] = df_residual['residual'] / df_residual['actual'] * 100
df_residual
# Out:
#        housing_median_age  total_rooms  median_income ocean_proximity  \
# 8179                 12.0       3876.0         4.0844       <1H OCEAN
# 5754                 20.0       3976.0         2.5387          INLAND
# 1976                 35.0       2976.0         4.2670        NEAR BAY
# 7369                 11.0       1996.0         3.5714          INLAND
# 2689                 16.0       2056.0         2.9576      NEAR OCEAN
# ...                   ...          ...            ...             ...
# 8676                 34.0       1078.0         4.5083       <1H OCEAN
# 12255                42.0       1370.0         4.4474       <1H OCEAN
# 3866                 30.0       2756.0         3.0329       <1H OCEAN
# 7658                 38.0       2809.0         1.8512          INLAND
# 6104                 24.0       6012.0         3.0043          INLAND
#
#        bedrooms_per_room  population_per_household    actual     prediction  \
# ...

# %%
#qq plot
import scipy.stats as stats
import matplotlib.pyplot as plt

stats.probplot(df_residual['residual'], dist="norm", plot=plt)
plt.title('Normal Q-Q Plot')
plt.show()

# %%
#shapiro test for normality
from scipy.stats import shapiro
stat, p = shapiro(df_residual['residual'])
print(p)
# interpret 
alpha = 0.05
if p > alpha:
    print('Sample looks Gaussian (fail to reject H0)')
    
else:
    print('Sample does not look Gaussian (reject H0)')
# Out:
# 4.524816298688021e-31
# Sample does not look Gaussian (reject H0)

# %% [markdown]
# Berdasarkan qq plot persebaran residual terlihat bahwa residual tidak terdistribusi normal. Hal ini terlihat dari pola yang tidak mengikuti garis diagonal pada qq plot karena di quartil -3 sudah keluar jalur atau underestimate dan pada kuartil 1 residualnya overestimate. Sehingga dapat disimpulkan bahwa residual tidak terdistribusi normal. dan juga setelah dicek menggunakan shapiro test didapatkan nilai p-value 0.5 yang berarti residual tidak terdistribusi normal bahkan setelah pengeliminasian multiculionerity menggunakan VIF. Dan kesimpulanya bahwa algoritma ini bias

# %% [markdown]
# ## Feature Importance

# %%
pipe['preprocessing'].get_feature_names_out()
# Out:
# array(['pipe_robust_scale__median_income',
#        'pipe_robust_scale__housing_median_age',
#        'pipe_robust_scale__bedrooms_per_room',
#        'pipe_robust_scale__population_per_household',
#        'pipe_robust_scale__total_rooms',
#        'pipe_ordinal_scale__ocean_proximity_<1H OCEAN',
#        'pipe_ordinal_scale__ocean_proximity_INLAND',
#        'pipe_ordinal_scale__ocean_proximity_NEAR BAY',
#        'pipe_ordinal_scale__ocean_proximity_NEAR OCEAN'], dtype=object)

# %%
pipe['model'].regressor_.feature_importances_
# Out:
# array([0.364379  , 0.05189592, 0.0767248 , 0.10750491, 0.06144493,
#        0.00418941, 0.32592288, 0.00433146, 0.00360669])

# %%
#feature importance in lightgbm before tuning
importances = pipe['model'].regressor_.feature_importances_
features = pipe['preprocessing'].get_feature_names_out()
indices = np.argsort(importances)[::-1]

plt.figure(figsize=(10, 8))
plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %% [markdown]
# Dari plot yang diberikan, terlihat bahwa beberapa fitur memiliki pengaruh yang signifikan terhadap nilai median_house_value (harga rumah median). Fitur-fitur tersebut adalah:
#
# 1. **Median Income**: Fitur ini juga memiliki dampak yang cukup besar. Ini menunjukkan bahwa pendapatan median rumah tangga di distrik tersebut mempengaruhi harga rumah. Distrik dengan pendapatan median rumah tangga yang lebih tinggi cenderung memiliki harga rumah yang lebih tinggi.
#
# 2. **Ocean Proximity**: Fitur ini tampak memiliki pengaruh yang besar terhadap harga rumah. Ini mengindikasikan bahwa lokasi rumah sangat berpengaruh terhadap harga. Rumah yang berlokasi di pinggir laut atau memiliki akses yang baik ke laut cenderung memiliki harga yang lebih tinggi daripada rumah yang berada di dalam daratan.
#
# 3. **Bedrooms Per Room**: Fitur ini juga memiliki pengaruh yang signifikan. Ini menunjukkan bahwa rasio kamar tidur terhadap jumlah kamar di distrik tersebut mempengaruhi harga rumah. Distrik dengan rasio kamar tidur terhadap jumlah kamar yang lebih tinggi cenderung memiliki harga rumah yang lebih rendah.

# %% [markdown]
# ### Limitation

# %%
df_copy.describe()
# Out:
#        housing_median_age   total_rooms  median_income  median_house_value  \
# count        12598.000000  12598.000000   12598.000000        12598.000000
# mean            26.889586   2664.969122       3.638759       183625.019606
# std             11.430492   2227.751635       1.505248        87810.085981
# min              1.000000      2.000000       0.499900        14999.000000
# 25%             17.000000   1453.000000       2.525000       114225.000000
# 50%             27.000000   2129.000000       3.436700       169100.000000
# 75%             36.000000   3170.750000       4.546900       237475.000000
# max             51.000000  32627.000000      15.000100       433800.000000
#
#        bedrooms_per_room  population_per_household
# count       12598.000000              12598.000000
# mean            0.214312                  3.078671
# std             0.055061                  7.050701
# min             0.100000                  0.750000
# ...

# %% [markdown]
# Model prediksi harga perumahan ini memiliki beberapa keterbatasan yang harus dipahami. Pertama, model tidak dapat memberikan prediksi yang akurat untuk properti dengan harga di atas 433800 USD. Artinya, jika Anda mencoba memprediksi nilai properti yang melebihi batas ini, hasil prediksinya mungkin tidak akurat dan bisa menghasilkan estimasi yang tidak sesuai dengan kenyataan.
#
# Penting untuk selalu mempertimbangkan batasan-batasan ini ketika menggunakan model prediksi ini. Model ini paling cocok digunakan untuk memprediksi harga perumahan dalam rentang harga yang sesuai dan untuk jenis properti yang telah dioptimalkan dalam proses pelatihan. Jika Anda memiliki kebutuhan untuk memprediksi properti di luar batasan ini atau untuk jenis properti yang berbeda, mungkin diperlukan pendekatan atau model yang berbeda yang dapat mempertimbangkan karakteristik yang lebih luas.

# %% [markdown]
# # 5. Conclusion
# Berdasarkan hasil model LGBM :
# - Dari 7 model yang diuji, LGBM merupakan model terbaik dengan nilai RMSE, MAE dan MAPE terkecil. yaitu MAPE : 0.212267, MAE : 35905, RMSE : 49802
# - `Ocean_proximity` merupakan fitur yang paling berpengaruh terhadap harga rumah. Rumah yang berlokasi di pinggir laut atau memiliki akses yang baik ke laut cenderung memiliki harga yang lebih tinggi daripada rumah yang berada di dalam daratan.
# - `Median_income` juga memiliki dampak yang cukup besar. Ini menunjukkan bahwa pendapatan median rumah tangga di distrik tersebut mempengaruhi harga rumah. Distrik dengan pendapatan median rumah tangga yang lebih tinggi cenderung memiliki harga rumah yang lebih tinggi.
# - Batasan model ini adalah tidak dapat memberikan prediksi yang akurat untuk properti dengan harga di atas 4338.000 USD. Artinya, jika Anda mencoba memprediksi nilai properti yang melebihi batas ini, hasil prediksinya mungkin tidak akurat dan bisa menghasilkan estimasi yang tidak sesuai dengan kenyataan. Dan model ini bias jadi harus ada pengembangan lebih lanjut

# %% [markdown]
# # 6. Recommendation

# %% [markdown]
# <b>1. Rekomendasi Berdasarkan Bisnis </b>
#
# Untuk mengoptimalkan profitabilitas, penting untuk mempertimbangkan lokasi tempat rumah dibangun serta memperhatikan pendapatan per kapita penduduk di sekitar daerah tersebut.
#
# <b>2. Rekomendasi Berdasarkan Model</b>
#
# Bisa dilakukan gridsearch untuk model dikarenakan saat ini hanya menggunakan random search dan n iter = 15.
#
# <b>3. Rekomendasi Berdasarkan Data</b>
#
# Untuk meningkatkan korelasi dengan target, dapat dilakukan dengan menambahkan fitur seperti ukuran bangunan, fasilitas parkir mobil, luas halaman rumah, dan keberadaan kolam renang. Selain itu, eksplorasi lebih lanjut terhadap variabel yang terkait dengan fasilitas di sekitar properti juga dapat memberikan dampak yang signifikan pada prediksi harga rumah. Pembaruan data terbaru tentang harga rumah di California juga memiliki potensi untuk meningkatkan kapasitas prediksi model.
#
# Untuk analisis terkini, perlu dilakukan pembaruan data harga rumah karena dataset yang digunakan sudah cukup usang (tahun 1990) dan kemungkinan telah terpengaruh oleh inflasi.

# %%
#save pickle
import pickle
#save model to sav file
with open('model_california_house.sav', 'wb') as f:
    pickle.dump(pipe, f)
    f.close()

#save transformer
